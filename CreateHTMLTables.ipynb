# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
Cjobs_df = pd.read_csv('datasets/Cleaned_jobs.csv')
print(Cjobs_df.head().to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>job_title</th>
#       <th>job_type</th>
#       <th>sector</th>
#       <th>City</th>
#       <th>State</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>IT Support Technician Job in Madison</td>
#       <td>Full Time</td>
#       <td>IT/Software Development</td>
#       <td>Madison</td>
#       <td>WI</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Business Reporter/Editor Job in Madison</td>
#       <td>Full Time</td>
#       <td>NaN</td>
#       <td>Madison</td>
#       <td>WI</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>Support Agent - GPS Systems Job in Racine</td>
#       <td>Full Time</td>
#       <td>Engineering</td>
#       <td>Racine</td>
#       <td>WI</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %%
UnDF=pd.read_csv('datasets/unemploymentData.csv')
print(UnDF.head().to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>2017 rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Hawaii</td>
#       <td>2.4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>North Dakota</td>
#       <td>2.6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>New Hampshire</td>
#       <td>2.7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Colorado</td>
#       <td>2.8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Nebraska</td>
#       <td>2.9</td>
#     </tr>
#   </tbody>
# </table>

# %%
popDF=pd.read_csv('datasets/populationData.csv')
print(popDF.head().to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>population</th>
#       <th>state</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4874747</td>
#       <td>Alabama</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>739795</td>
#       <td>Alaska</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7016270</td>
#       <td>Arizona</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3004279</td>
#       <td>Arkansas</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>39536653</td>
#       <td>California</td>
#     </tr>
#   </tbody>
# </table>

# %%
StateDF=pd.read_csv('datasets/stateAbbreviations.csv')
print(StateDF.head().to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Abbreviation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alabama</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Alaska</td>
#       <td>AK</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Arizona</td>
#       <td>AZ</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Arkansas</td>
#       <td>AR</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>California</td>
#       <td>CA</td>
#     </tr>
#   </tbody>
# </table>

# %%
Final=pd.read_csv('datasets/final.csv')
print(Final.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>population</th>
#       <th>job_count</th>
#       <th>unemp_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AK</td>
#       <td>739795</td>
#       <td>1</td>
#       <td>7.2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AL</td>
#       <td>4874747</td>
#       <td>130</td>
#       <td>4.4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AR</td>
#       <td>3004279</td>
#       <td>73</td>
#       <td>3.7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AZ</td>
#       <td>7016270</td>
#       <td>45</td>
#       <td>4.9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>CA</td>
#       <td>39536653</td>
#       <td>1605</td>
#       <td>4.8</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>CO</td>
#       <td>5607154</td>
#       <td>427</td>
# ...
