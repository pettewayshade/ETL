# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

import pyodbc
import urllib
import sqlite3

# %% [markdown]
# ### Store CSV into DataFrame

# %%
#Pulls in Jobs Data
csv_file = "monster_com-job_sample.csv"
jobs_df = pd.read_csv(csv_file)
jobs_df.head()
# Out:
#                     country country_code date_added has_expired  \
# 0  United States of America           US        NaN          No
# 1  United States of America           US        NaN          No
# 2  United States of America           US        NaN          No
# 3  United States of America           US        NaN          No
# 4  United States of America           US        NaN          No
#
#           job_board                                    job_description  \
# 0  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1  jobs.monster.com  The Wisconsin State Journal is seeking a flexi...
# 2  jobs.monster.com  Report this job About the Job DePuy Synthes Co...
# 3  jobs.monster.com  Why Join Altec? If you’re considering a career...
# 4  jobs.monster.com  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# 1            Business Reporter/Editor Job in Madison            Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time, Employee
# 3                    Engineer - Quality Job in Dixon            Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill   Full Time Employee
#
#                                             location  \
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA
#
#                       organization  \
# 0                              NaN
# 1          Printing and Publishing
# 2  Personal and Household Services
# 3                 Altec Industries
# 4                           Retail
#
#                                             page_url salary  \
# 0  http://jobview.monster.com/it-support-technici...    NaN
# 1  http://jobview.monster.com/business-reporter-e...    NaN
# 2  http://jobview.monster.com/senior-training-lea...    NaN
# 3  http://jobview.monster.com/engineer-quality-jo...    NaN
# 4  http://jobview.monster.com/shift-supervisor-pa...    NaN
#
#                        sector                           uniq_id
# 0     IT/Software Development  11d599f229a80023d2f40e7c52cd941e
# 1                         NaN  e4cbb126dabf22159aff90223243ff2a
# 2                         NaN  839106b353877fa3d896ffb9c1fe01c0
# 3   Experienced (Non-Manager)  58435fcab804439efdcaa7ecca0fd783
# 4  Project/Program Management  64d0272dc8496abfd9523a8df63c184c

# %% [markdown]
# ### Create new data with select columns

# %%
#Copy Columns of Interest.
new_jobs_df = jobs_df[['job_title', 'job_type', 'sector','location']].copy()
new_jobs_df.head()
# Out:
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# 1            Business Reporter/Editor Job in Madison            Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time, Employee
# 3                    Engineer - Quality Job in Dixon            Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill   Full Time Employee
#
#                        sector  \
# 0     IT/Software Development
# 1                         NaN
# 2                         NaN
# 3   Experienced (Non-Manager)
# 4  Project/Program Management
#
#                                             location
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA

# %%
#Renames job types.
new_jobs_df['job_type'] = new_jobs_df['job_type'].map(
    lambda x: x if pd.isnull(x) else 'Full Time' if 'Full' in x else 'Part Time' if 'Part' in x else 'Other'
)

new_jobs_df.head()
# Out:
#                                            job_title   job_type  \
# 0               IT Support Technician Job in Madison  Full Time
# 1            Business Reporter/Editor Job in Madison  Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time
# 3                    Engineer - Quality Job in Dixon  Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill  Full Time
#
#                        sector  \
# 0     IT/Software Development
# 1                         NaN
# 2                         NaN
# 3   Experienced (Non-Manager)
# 4  Project/Program Management
#
#                                             location
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA

# %%
#Parsing through the location column and cleaning it up
new_jobs_df=new_jobs_df[new_jobs_df['location'].str.len() < 30]

location=new_jobs_df['location'].str.split(',')
new_jobs_df['City']=location.str[0]
new_jobs_df['State']=location.str[1].str[0:3]


new_jobs_df.reset_index(inplace=True, drop=True)

# %%
#Drops the rows with NAs in the State C
new_jobs_df.dropna(subset=['State'],inplace=True)

new_jobs_df.drop(['location'],axis=1,inplace=True)

# %%
new_jobs_df.head()
# Out:
#                                                job_title   job_type  \
# 0                   IT Support Technician Job in Madison  Full Time
# 1                Business Reporter/Editor Job in Madison  Full Time
# 2                        Engineer - Quality Job in Dixon  Full Time
# 3           Shift Supervisor - Part-Time Job in Camphill  Full Time
# 4      Construction PM - Charlottesville Job in Charl...  Full Time
# 6                           Mailroom Clerk Job in Austin  Full Time
# 7                              Housekeeper Job in Austin  Part Time
# 8      Video Data Management /Transportation Technici...        NaN
# 9          Aflac Insurance Sales Agent Job in Berryville  Full Time
# 10                       Sales Associate Job in Columbus  Full Time
# 11                      Junior Proofreader Job in Boston  Full Time
# 12     Primrose Private Preschool Teacher Job in Houston  Full Time
# 13                         Superintendent Job in Houston  Full Time
# 14     Engineer II - Outside Plant Engineer Job in De...  Full Time
# 16     Pest Control Technician – Field Service Rep (E...  Full Time
# 17     Content Developer for MATLAB Code Generation J...  Full Time
# 18     Technician - Robot & Multi-Axis CNC Field Serv...  Full Time
# 19            Business & Strategy Analyst Job in Houston  Full Time
# 20            Real Estate Underwriter -Jr Job in Houston  Full Time
# 22                Estimator - Construction Job in Denver  Full Time
# 23     Construction Healthcare Superintendent / Hospi...  Full Time
# 24     Biomedical Engineering Director Job in San Carlos  Full Time
# 25     AT&T Business Sales Leadership Development Pro...        NaN
# 26     Traveling Customer Training Professional Job i...  Full Time
# 27                              Resident Care Specialist  Full Time
# 28     Mechanical Engineer - FEA/Mechanical Modeling/...  Full Time
# 29         RECREATION THERAPY ASSISTANT Job in Knoxville  Full Time
# 30     Machine Control Systems Engineer - BSEE Job in...  Full Time
# 31                      Equipment Operator Job in Denver  Full Time
# 32        Associate Product Developer Job in Saint Louis  Full Time
# ...                                                  ...        ...
# 20240        Packaging Design Engineer Job in Cincinnati  Full Time
# 20241  Site Director - Xavier University Job in Cinci...  Full Time
# 20242  EXECUTIVE CHEF WEST CHESTER OHIO $K-$K PLUS! B...  Full Time
# 20243  Restaurant Manager - Retail Food Service Manag...  Full Time
# 20244  Accounts Payable Accounting Manager Job in Cin...  Full Time
# 20245  Medical Collections Representative Job in Chicago  Full Time
# 20246        Customer Business Manager Job in Cincinnati  Full Time
# 20247    BB Customer Service Associate Job in Cincinnati  Full Time
# 20248     Outside Sales Representative Job in Cincinnati  Full Time
# 20249              Cincinnati Job Fair Job in Cincinnati  Part Time
# 20250        Enterprise Search Analyst Job in Cincinnati  Full Time
# 20251           Journeyman Electrician Job in Cincinnati  Full Time
# 20252     Help Desk Support Engineer Job in West Chester  Full Time
# 20253  Senior Accountant for a Digital Publisher in t...  Full Time
# 20255  Now Hiring Data Entry Reps and Mail Clerks- ca...  Part Time
# 20256  General Manager of Sales & Marketing Job in Ci...  Full Time
# 20257                       Audit Manager Job in Chicago  Full Time
# 20258                        Experienced Territory Sales  Full Time
# 20259                       Accountant Job in Cincinnati  Full Time
# 20260      Accounts Receivable Specialist Job in Chicago  Full Time
# 20261                     Finance Manager Job in Chicago  Full Time
# 20262     Licensed Practical Nurse LPN Job in Cincinnati  Full Time
# 20263  Customer Service Professionals Consider a Care...  Full Time
# 20264       Patient Access Representative Job in Chicago  Full Time
# 20265  Immediate Customer Service Position Job in Cin...  Part Time
# 20266  Assistant Vice President - Controller Job in C...  Full Time
# 20267                       Accountant Job in Cincinnati  Full Time
# 20268                    AEM/CQ developer Job in Chicago  Full Time
# 20269  Electrician - Experienced Forging Electrician ...  Full Time
# 20270           Contract Administrator Job in Cincinnati  Full Time
#
#                                                   sector             City  \
# 0                                IT/Software Development          Madison
# 1                                                    NaN          Madison
# 2                              Experienced (Non-Manager)            Dixon
# 3                             Project/Program Management         Camphill
# 4                              Experienced (Non-Manager)  Charlottesville
# 6                              Experienced (Non-Manager)           Austin
# 7                           Customer Support/Client Care           Austin
# 8                                                    NaN     Chesterfield
# 9                           Customer Support/Client Care       Berryville
# 10                          Customer Support/Client Care         Columbus
# 11                                                   NaN           Boston
# 12                                           Entry Level          Houston
# 13                  Building Construction/Skilled Trades          Houston
# 14                                                   NaN       Des Moines
# 16                       Installation/Maintenance/Repair           Denver
# 17                             Experienced (Non-Manager)           Natick
# 18                             Experienced (Non-Manager)      Carter Lake
# 19                         Business/Strategic Management          Houston
# 20                          Accounting/Finance/Insurance          Houston
# 22                                                   NaN           Denver
# 23                                                   NaN          Houston
# 24                                                   NaN       San Carlos
# 25                                                   NaN           Denver
# 26                          Customer Support/Client Care          Houston
# 27                                                   NaN          Houston
# 28                                                   NaN      Mounds View
# 29                                                   NaN        Knoxville
# 30                             Experienced (Non-Manager)           Aurora
# 31                                                   NaN           Denver
# 32                             Experienced (Non-Manager)      Saint Louis
# ...                                                  ...              ...
# 20240                                        Engineering       Cincinnati
# 20241                                                NaN       Cincinnati
# 20242              Manager (Manager/Supervisor of Staff)     West Chester
# 20243                          Food Services/Hospitality       Cincinnati
# 20244                          Experienced (Non-Manager)       Cincinnati
# 20245                       Customer Support/Client Care          Chicago
# 20246                                  Marketing/Product       Cincinnati
# 20247                          Experienced (Non-Manager)       Cincinnati
# 20248                          Experienced (Non-Manager)       Cincinnati
# 20249                                                NaN       Cincinnati
# 20250                                                NaN       Cincinnati
# 20251                                                NaN       Cincinnati
# 20252                          Experienced (Non-Manager)     West Chester
# 20253                       Accounting/Finance/Insurance          Chicago
# 20255                                                NaN       Cincinnati
# 20256          Executive (SVP, VP, Department Head, etc)       Cincinnati
# 20257              Manager (Manager/Supervisor of Staff)          Chicago
# 20258                          Experienced (Non-Manager)          Chicago
# 20259                                        Entry Level       Cincinnati
# 20260                       Accounting/Finance/Insurance          Chicago
# 20261                      Business/Strategic Management          Chicago
# 20262                                     Medical/Health       Cincinnati
# 20263  Field SalesGeneral/Other: Sales/Business Devel...       Cincinnati
# 20264                       Customer Support/Client Care          Chicago
# 20265                                        Entry Level       Cincinnati
# 20266                                                NaN       Cincinnati
# 20267              Manager (Manager/Supervisor of Staff)       Cincinnati
# 20268                                                NaN          Chicago
# 20269                    Installation/Maintenance/Repair          Chicago
# 20270                          Experienced (Non-Manager)       Cincinnati
#
#       State
# 0        WI
# 1        WI
# 2        CA
# 3        PA
# 4        VA
# 6        TX
# 7        TX
# 8        MO
# 9        VA
# 10       IN
# 11       MA
# 12       TX
# 13       TX
# 14       IA
# 16       CO
# 17       MA
# 18       IA
# 19       TX
# 20       TX
# 22       CO
# 23       TX
# 24       CA
# 25       CO
# 26       TX
# 27       TX
# 28       MN
# 29       TN
# 30       IL
# 31       CO
# 32       MO
# ...     ...
# 20240    OH
# 20241    OH
# 20242    OH
# 20243    OH
# 20244    OH
# 20245    IL
# 20246    OH
# 20247    OH
# 20248    OH
# 20249    OH
# 20250    OH
# 20251    OH
# 20252    OH
# 20253    IL
# 20255    OH
# 20256    OH
# 20257    IL
# 20258    IL
# 20259    OH
# 20260    IL
# 20261    IL
# 20262    OH
# 20263    OH
# 20264    IL
# 20265    OH
# 20266    OH
# 20267    OH
# 20268    IL
# 20269    IL
# 20270    OH
#
# [18525 rows x 5 columns]

# %%
#params=urllib.parse.quote_plus('Driver={ODBC Driver 13 for SQL Server};Server=tcp:etlproject.database.windows.net,1433;Database=ETLProject;Uid=datascience@etlproject;Pwd=Abcde12345;Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;')

#engine = create_engine("mssql+pyodbc:///?odbc_connect=%s" % params)

#sqlite3.connect('etlproject.sqlite')

#engine = create_engine("sqlite:///etlproject.sqlite")

# %%
new_jobs_df.to_csv('Cleaned_jobs.csv')

# %%
# Out:
#                                            job_title   job_type  \
# 0               IT Support Technician Job in Madison  Full Time
# 1            Business Reporter/Editor Job in Madison  Full Time
# 2                    Engineer - Quality Job in Dixon  Full Time
# 3       Shift Supervisor - Part-Time Job in Camphill  Full Time
# 4  Construction PM - Charlottesville Job in Charl...  Full Time
#
#                        sector             City State
# 0     IT/Software Development          Madison    WI
# 1                        None          Madison    WI
# 2   Experienced (Non-Manager)            Dixon    CA
# 3  Project/Program Management         Camphill    PA
# 4   Experienced (Non-Manager)  Charlottesville    VA
