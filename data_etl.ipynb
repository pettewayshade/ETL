# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "monster_com-job_sample.csv"
jobs_df = pd.read_csv(csv_file)
jobs_df.head()
# Out:
#                     country country_code date_added has_expired  \
# 0  United States of America           US        NaN          No
# 1  United States of America           US        NaN          No
# 2  United States of America           US        NaN          No
# 3  United States of America           US        NaN          No
# 4  United States of America           US        NaN          No
#
#           job_board                                    job_description  \
# 0  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1  jobs.monster.com  The Wisconsin State Journal is seeking a flexi...
# 2  jobs.monster.com  Report this job About the Job DePuy Synthes Co...
# 3  jobs.monster.com  Why Join Altec? If you’re considering a career...
# 4  jobs.monster.com  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# 1            Business Reporter/Editor Job in Madison            Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time, Employee
# 3                    Engineer - Quality Job in Dixon            Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill   Full Time Employee
#
#                                             location  \
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA
#
#                       organization  \
# 0                              NaN
# 1          Printing and Publishing
# 2  Personal and Household Services
# 3                 Altec Industries
# 4                           Retail
#
#                                             page_url salary  \
# 0  http://jobview.monster.com/it-support-technici...    NaN
# 1  http://jobview.monster.com/business-reporter-e...    NaN
# 2  http://jobview.monster.com/senior-training-lea...    NaN
# 3  http://jobview.monster.com/engineer-quality-jo...    NaN
# 4  http://jobview.monster.com/shift-supervisor-pa...    NaN
#
#                        sector                           uniq_id
# 0     IT/Software Development  11d599f229a80023d2f40e7c52cd941e
# 1                         NaN  e4cbb126dabf22159aff90223243ff2a
# 2                         NaN  839106b353877fa3d896ffb9c1fe01c0
# 3   Experienced (Non-Manager)  58435fcab804439efdcaa7ecca0fd783
# 4  Project/Program Management  64d0272dc8496abfd9523a8df63c184c

# %% [markdown]
# ### Create new data with select columns

# %%
new_jobs_df = jobs_df[['job_title', 'job_type', 'sector','location']].copy()
new_jobs_df.head()
# Out:
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# 1            Business Reporter/Editor Job in Madison            Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time, Employee
# 3                    Engineer - Quality Job in Dixon            Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill   Full Time Employee
#
#                        sector  \
# 0     IT/Software Development
# 1                         NaN
# 2                         NaN
# 3   Experienced (Non-Manager)
# 4  Project/Program Management
#
#                                             location
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA

# %%
#Renames job types.
new_jobs_df['job_type'] = new_jobs_df['job_type'].map(
    lambda x: x if pd.isnull(x) else 'Full Time' if 'Full' in x else 'Part Time' if 'Part' in x else 'Other'
)

new_jobs_df.head()
# Out:
#                                            job_title   job_type  \
# 0               IT Support Technician Job in Madison  Full Time
# 1            Business Reporter/Editor Job in Madison  Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time
# 3                    Engineer - Quality Job in Dixon  Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill  Full Time
#
#                        sector  \
# 0     IT/Software Development
# 1                         NaN
# 2                         NaN
# 3   Experienced (Non-Manager)
# 4  Project/Program Management
#
#                                             location
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA

# %%
new_jobs_df=new_jobs_df[new_jobs_df['location'].str.len() < 30]

location=new_jobs_df['location'].str.split(',')
new_jobs_df['City']=location.str[0]
new_jobs_df['State']=location.str[1].str[0:3]

new_jobs_df.loc[new_jobs_df['State'] != np.nan]
# Out:
#                                                job_title   job_type  \
# 0                   IT Support Technician Job in Madison  Full Time
# 1                Business Reporter/Editor Job in Madison  Full Time
# 3                        Engineer - Quality Job in Dixon  Full Time
# 4           Shift Supervisor - Part-Time Job in Camphill  Full Time
# 5      Construction PM - Charlottesville Job in Charl...  Full Time
# 6      CyberCoders Job Application for Principal QA E...  Full Time
# 7                           Mailroom Clerk Job in Austin  Full Time
# 8                              Housekeeper Job in Austin  Part Time
# 9      Video Data Management /Transportation Technici...        NaN
# 10         Aflac Insurance Sales Agent Job in Berryville  Full Time
# 11                       Sales Associate Job in Columbus  Full Time
# 12                      Junior Proofreader Job in Boston  Full Time
# 13     Primrose Private Preschool Teacher Job in Houston  Full Time
# 14                         Superintendent Job in Houston  Full Time
# 15     Engineer II - Outside Plant Engineer Job in De...  Full Time
# 16     Horizontal Construction Engineers Job in Wades...        NaN
# 17     Pest Control Technician – Field Service Rep (E...  Full Time
# 18     Content Developer for MATLAB Code Generation J...  Full Time
# 19     Technician - Robot & Multi-Axis CNC Field Serv...  Full Time
# 20            Business & Strategy Analyst Job in Houston  Full Time
# 21            Real Estate Underwriter -Jr Job in Houston  Full Time
# 22     Combat Engineer - Construction and Engineering...        NaN
# 23                Estimator - Construction Job in Denver  Full Time
# 24     Construction Healthcare Superintendent / Hospi...  Full Time
# 25     Biomedical Engineering Director Job in San Carlos  Full Time
# 26     AT&T Business Sales Leadership Development Pro...        NaN
# 27     Traveling Customer Training Professional Job i...  Full Time
# 28                              Resident Care Specialist  Full Time
# 30     Mechanical Engineer - FEA/Mechanical Modeling/...  Full Time
# 31         RECREATION THERAPY ASSISTANT Job in Knoxville  Full Time
# ...                                                  ...        ...
# 21970  Site Director - Xavier University Job in Cinci...  Full Time
# 21971  EXECUTIVE CHEF WEST CHESTER OHIO $K-$K PLUS! B...  Full Time
# 21972  Restaurant Manager - Retail Food Service Manag...  Full Time
# 21973  Accounts Payable Accounting Manager Job in Cin...  Full Time
# 21974  Medical Collections Representative Job in Chicago  Full Time
# 21975        Customer Business Manager Job in Cincinnati  Full Time
# 21976    BB Customer Service Associate Job in Cincinnati  Full Time
# 21977     Outside Sales Representative Job in Cincinnati  Full Time
# 21978              Cincinnati Job Fair Job in Cincinnati  Part Time
# 21979        Enterprise Search Analyst Job in Cincinnati  Full Time
# 21980           Journeyman Electrician Job in Cincinnati  Full Time
# 21981     Help Desk Support Engineer Job in West Chester  Full Time
# 21982  Senior Accountant for a Digital Publisher in t...  Full Time
# 21983                   Custodian Lead Job in Cincinnati  Full Time
# 21984  Now Hiring Data Entry Reps and Mail Clerks- ca...  Part Time
# 21985  General Manager of Sales & Marketing Job in Ci...  Full Time
# 21986                       Audit Manager Job in Chicago  Full Time
# 21987                        Experienced Territory Sales  Full Time
# 21988                       Accountant Job in Cincinnati  Full Time
# 21989      Accounts Receivable Specialist Job in Chicago  Full Time
# 21990                     Finance Manager Job in Chicago  Full Time
# 21991     Licensed Practical Nurse LPN Job in Cincinnati  Full Time
# 21992  Customer Service Professionals Consider a Care...  Full Time
# 21993       Patient Access Representative Job in Chicago  Full Time
# 21994  Immediate Customer Service Position Job in Cin...  Part Time
# 21995  Assistant Vice President - Controller Job in C...  Full Time
# 21996                       Accountant Job in Cincinnati  Full Time
# 21997                    AEM/CQ developer Job in Chicago  Full Time
# 21998  Electrician - Experienced Forging Electrician ...  Full Time
# 21999           Contract Administrator Job in Cincinnati  Full Time
#
#                                                   sector  \
# 0                                IT/Software Development
# 1                                                    NaN
# 3                              Experienced (Non-Manager)
# 4                             Project/Program Management
# 5                              Experienced (Non-Manager)
# 6                                                    NaN
# 7                              Experienced (Non-Manager)
# 8                           Customer Support/Client Care
# 9                                                    NaN
# 10                          Customer Support/Client Care
# 11                          Customer Support/Client Care
# 12                                                   NaN
# 13                                           Entry Level
# 14                  Building Construction/Skilled Trades
# 15                                                   NaN
# 16     Civil & Structural EngineeringGeneral/Other: E...
# 17                       Installation/Maintenance/Repair
# 18                             Experienced (Non-Manager)
# 19                             Experienced (Non-Manager)
# 20                         Business/Strategic Management
# 21                          Accounting/Finance/Insurance
# 22                            General/Other: Engineering
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                          Customer Support/Client Care
# 28                                                   NaN
# 30                                                   NaN
# 31                                                   NaN
# ...                                                  ...
# 21970                                                NaN
# 21971              Manager (Manager/Supervisor of Staff)
# 21972                          Food Services/Hospitality
# 21973                          Experienced (Non-Manager)
# 21974                       Customer Support/Client Care
# 21975                                  Marketing/Product
# 21976                          Experienced (Non-Manager)
# 21977                          Experienced (Non-Manager)
# 21978                                                NaN
# 21979                                                NaN
# 21980                                                NaN
# 21981                          Experienced (Non-Manager)
# 21982                       Accounting/Finance/Insurance
# 21983                    Installation/Maintenance/Repair
# 21984                                                NaN
# 21985          Executive (SVP, VP, Department Head, etc)
# 21986              Manager (Manager/Supervisor of Staff)
# 21987                          Experienced (Non-Manager)
# 21988                                        Entry Level
# 21989                       Accounting/Finance/Insurance
# 21990                      Business/Strategic Management
# 21991                                     Medical/Health
# 21992  Field SalesGeneral/Other: Sales/Business Devel...
# 21993                       Customer Support/Client Care
# 21994                                        Entry Level
# 21995                                                NaN
# 21996              Manager (Manager/Supervisor of Staff)
# 21997                                                NaN
# 21998                    Installation/Maintenance/Repair
# 21999                          Experienced (Non-Manager)
#
#                       location                     City State
# 0            Madison, WI 53702                  Madison    WI
# 1            Madison, WI 53708                  Madison    WI
# 3                    Dixon, CA                    Dixon    CA
# 4                 Camphill, PA                 Camphill    PA
# 5          Charlottesville, VA          Charlottesville    VA
# 6      Contact name Tony Zerio  Contact name Tony Zerio   NaN
# 7             Austin, TX 73301                   Austin    TX
# 8             Austin, TX 78746                   Austin    TX
# 9             Chesterfield, MO             Chesterfield    MO
# 10        Berryville, VA 22611               Berryville    VA
# 11                Columbus, IN                 Columbus    IN
# 12                  Boston, MA                   Boston    MA
# 13           Houston, TX 77098                  Houston    TX
# 14                 Houston, TX                  Houston    TX
# 15        Des Moines, IA 50317               Des Moines    IA
# 16             Wadesboro 28170          Wadesboro 28170   NaN
# 17                  Denver, CO                   Denver    CO
# 18                  Natick, MA                   Natick    MA
# 19       Carter Lake, IA 51510              Carter Lake    IA
# 20                 Houston, TX                  Houston    TX
# 21           Houston, TX 77027                  Houston    TX
# 22              La Porte 46350           La Porte 46350   NaN
# 23            Denver, CO 80215                   Denver    CO
# 24                 Houston, TX                  Houston    TX
# 25        San Carlos, CA 94070               San Carlos    CA
# 26                  Denver, CO                   Denver    CO
# 27           Houston, TX 77040                  Houston    TX
# 28                 Houston, TX                  Houston    TX
# 30       Mounds View, MN 55112              Mounds View    MN
# 31               Knoxville, TN                Knoxville    TN
# ...                        ...                      ...   ...
# 21970           Cincinnati, OH               Cincinnati    OH
# 21971         West Chester, OH             West Chester    OH
# 21972           Cincinnati, OH               Cincinnati    OH
# 21973     Cincinnati, OH 45202               Cincinnati    OH
# 21974        Chicago, IL 60603                  Chicago    IL
# 21975     Cincinnati, OH 45202               Cincinnati    OH
# 21976           Cincinnati, OH               Cincinnati    OH
# 21977     Cincinnati, OH 45202               Cincinnati    OH
# 21978     Cincinnati, OH 45226               Cincinnati    OH
# 21979     Cincinnati, OH 45202               Cincinnati    OH
# 21980           Cincinnati, OH               Cincinnati    OH
# 21981         West Chester, OH             West Chester    OH
# 21982        Chicago, IL 60603                  Chicago    IL
# 21983                Location:                Location:   NaN
# 21984     Cincinnati, OH 45214               Cincinnati    OH
# 21985           Cincinnati, OH               Cincinnati    OH
# 21986        Chicago, IL 60601                  Chicago    IL
# 21987        Chicago, IL 60602                  Chicago    IL
# 21988     Cincinnati, OH 45249               Cincinnati    OH
# 21989        Chicago, IL 60603                  Chicago    IL
# 21990        Chicago, IL 60603                  Chicago    IL
# 21991     Cincinnati, OH 45236               Cincinnati    OH
# 21992     Cincinnati, OH 45237               Cincinnati    OH
# 21993        Chicago, IL 60603                  Chicago    IL
# 21994     Cincinnati, OH 45202               Cincinnati    OH
# 21995           Cincinnati, OH               Cincinnati    OH
# 21996     Cincinnati, OH 45236               Cincinnati    OH
# 21997        Chicago, IL 60602                  Chicago    IL
# 21998        Chicago, IL 60609                  Chicago    IL
# 21999           Cincinnati, OH               Cincinnati    OH
#
# [20271 rows x 6 columns]

# %% [markdown]
# ### Store JSON data into a DataFrame

# %%
json_file = "../Resources/customer_location.json"
customer_location_df = pd.read_json(json_file)
customer_location_df.head()
# Out:
#                  address  id  latitude  longitude  us_state
# 0  043 Mockingbird Place   1   39.1682   -86.5186   Indiana
# 1       4 Prentice Point   2   41.0938   -85.0707   Indiana
# 2      46 Derek Junction   3   32.7673   -96.7776     Texas
# 3  11966 Old Shore Place   4   39.0350   -94.3567  Missouri
# 4     5 Evergreen Circle   5   40.7808   -73.9772  New York

# %% [markdown]
# ### Clean DataFrame

# %%
new_customer_location_df = customer_location_df[["id", "address", "us_state"]].copy()
new_customer_location_df.head()
# Out:
#    id                address  us_state
# 0   1  043 Mockingbird Place   Indiana
# 1   2       4 Prentice Point   Indiana
# 2   3      46 Derek Junction     Texas
# 3   4  11966 Old Shore Place  Missouri
# 4   5     5 Evergreen Circle  New York

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "<insert user name>:<insert password>@127.0.0.1/customer_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['customer_location', 'customer_name']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
new_customer_data_df.to_sql(name='customer_name', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database

# %%
new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from customer_name', con=engine).head()
# Out:
#    id first_name last_name
# 0   1    Benetta   Cancott
# 1   2     Lilyan    Cherry
# 2   3    Ezekiel   Benasik
# 3   4    Kennedy     Atlay
# 4   5    Sanford    Salmen

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from customer_location', con=engine).head()
# Out:
#    id                address  us_state
# 0   1  043 Mockingbird Place   Indiana
# 1   2       4 Prentice Point   Indiana
# 2   3      46 Derek Junction     Texas
# 3   4  11966 Old Shore Place  Missouri
# 4   5     5 Evergreen Circle  New York
